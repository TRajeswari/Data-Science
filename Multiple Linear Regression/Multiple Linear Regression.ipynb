# %%
import pandas as pd
df = pd.read_csv("D:\\My Classes\\Recordings\\Data\\Regression\\Cars_4vars.csv")
df.shape
# Out:
# (81, 5)

# %%
# EDA
import matplotlib.pyplot as plt
plt.scatter(df['HP'],df["MPG"])
plt.xlabel("HP")
plt.ylabel("MPG")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['SP'],df["MPG"])
plt.xlabel("SP")
plt.ylabel("MPG")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['VOL'],df["MPG"])
plt.xlabel("VOL")
plt.ylabel("MPG")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['WT'],df["MPG"])
plt.xlabel("WT")
plt.ylabel("MPG")
plt.show()

# %%
df.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
# data cleaning
df.isnull().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
y = df["MPG"]

# %%
# x = df[["HP"]]
# x = df[["HP","SP"]]
#x = df[["HP","VOL"]]
x = df[["SP","VOL"]]
# x = df[["HP","SP",'VOL']]
# x = df[["HP","SP",'VOL','WT']]

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x,y)
Y_pred = LR.predict(x)


from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y,Y_pred)
import numpy as np
RMSE = np.sqrt(mse)
print("Root Mean squared error:", RMSE.round(2))
r2 = r2_score(y,Y_pred)
print("R square:", r2.round(2))
# Out:
# Root Mean squared error: 5.09
# R square: 0.68
